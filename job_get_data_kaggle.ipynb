# %%
from pathlib import Path
import zipfile

# Install Kaggle API
# %pip install kaggle

# Download dataset using Kaggle API
# Note: You need to set up Kaggle API credentials first
# Create a kaggle.json file with your API token from kaggle.com/settings
# Place it at ~/.kaggle/kaggle.json or upload it to dbutils.secrets
# !kaggle datasets download -d testdatabox/finance-fraud-and-loans-dataset-testdatabox -p data/zip

# Extract the downloaded zip file
output = Path("data/zip/finance-fraud-and-loans-dataset-testdatabox.zip")
if output.exists():
    with zipfile.ZipFile(output, "r") as zip_ref:
        zip_ref.extractall("data/raw")
    print("Download e extração concluídos!")
else:
    print(f"Zip file not found at {output}. Please check Kaggle API authentication.")
